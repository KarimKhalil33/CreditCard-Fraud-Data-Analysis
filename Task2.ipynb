# %% [markdown]
# # Task 2: Using Seaborn for Pokemon Visualizations
#
# We will learn more about `seaborn` later in the course, but for now we will show you some very basic functionality about creating some plots.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2.1 Load your saved dataset from Task 1
#
# Use the `read_csv()` function from the `pandas` package to load the dataset you saved in Task 1, so we can use it in this notebook.

# %%
df = pd.read_csv('data/lab05_task1.csv')

# %%
df = pd.read_csv('https://github.com/firasm/bits/raw/master/pokemon.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  Total    HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison    318  45.0    49.0
# 1      2                Ivysaur    Grass  Poison    405  60.0    62.0
# 2      3               Venusaur    Grass  Poison    525  80.0    82.0
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80.0   100.0
# 4      4             Charmander     Fire     NaN    309  39.0    52.0
# ..   ...                    ...      ...     ...    ...   ...     ...
# 795  719                Diancie     Rock   Fairy    600  50.0   100.0
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50.0   160.0
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80.0   110.0
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80.0   160.0
# 799  721              Volcanion     Fire   Water    600  80.0   110.0
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49.0     65.0     65.0     45           1      False
# ...

# %% [markdown]
# ## 2.2: Plot Pokemon `Attack` vs. `Speed` using `seaborn`
#
# For this plot, you will be creating a **[scatter plot](https://seaborn.pydata.org/examples/different_scatter_variables.html)** which just plots two quantitative axes (`Attack` and `Speed`).
#
# Note: Most `seaborn` plotting functions return an "Axis object" as the returned value, and it's convention to store that as a variable.
# So you would do something like:
#
# ```
# ax_pokemon_plot1 = sns.scatterplot(...)
# ```
#
#
# ### Sample Output
#
# ![Seaborn plot of Pokemon Attack vs. Speed](images/pokemon_attack_speed.png)
#
# As you can see, this plot doesn't look too good right now, it's missing a title, the font sizes are very small, there are a lot of distracting visual elements (borders, borders around the points), as well as some "overplotting" (points on top of each other).
# In the next few questions, we will fix most of these issues and leave "overplotting" to later on in the course.

# %%
import seaborn as sns
ax_pokemon_plot1 = sns.scatterplot(data=df, x='Attack', y='Speed')
print(ax_pokemon_plot1)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ### 2.2: Set the Seaborn figure theme and scale up the text in the figures
#
# There are five preset Seaborn styles (or themes): `darkgrid`, `whitegrid`, `dark`, `white`, and `ticks`.
# They are each suited to different applications and personal preferences.
# You can see what they look like [here](https://seaborn.pydata.org/tutorial/aesthetics.html#seaborn-figure-styles).
#
# Hint: You will need to use the `font_scale` property of the `set_theme()` function in Seaborn.
#
# Once you've done that, create the same plot as in 2.1 and confirm that it looks bigger. Once you are able to confirm this, you will see all subsequent plots in this Jupyter Notebook using the same theme.
#
# Remember to copy this code above to your other Jupyter Notebooks as well!!
#
# ### Sample Output
#
# Your plot should now look something like this:
#
# ![Seaborn plot of Pokemon Attack vs. Speed, with larger text and fewer borders](images/pokemon_attack_speed.png)
#
# Note: Most `seaborn` plotting functions return an "Axis object" as the returned value, and it's convention to store that as a variable.
# Remember that you've already stored the Axis object from Task 1 as a variable, and to re-show the figure with the new theme, you just have to use `ax_pokemon_plot1.figure`
# ```
# # Your solution here for setting the figure theme and scaling up the text
#
# # Reshow the figure
# ax_pokemon_plot1.figure
# ```
#
# A bit of an improvement for sure!

# %%
import pandas as pd
import seaborn as sns

pokemon = pd.read_csv('data/lab05_task1.csv', index_col=0)
sns.set_theme(style="darkgrid", font_scale=1.5)
ax_pokemon_plot1 = sns.scatterplot(x='Attack', y='Speed', data=pokemon)
print(ax_pokemon_plot1)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %% [markdown]
# ### 2.3 Update axis labels and figure titles
#
# A plot isn't complete until it clearly communicates its intent and purpose, so we need to add figure titles, clearer axis labels. Also, we want to make the bottom left corner of the plot exactly at the coordinate **(0,0)**.
#
# For the plot you created above, update the following using `ax_pokemon_plot1.set(...)` :
#
# - Figure Title: "Relationship between Pokemon Attack and Speed"
# - x-axis label: "Pokemon Attack Points (0-190 pts)"
# - y-axis label: "Pokemon Speed Points (0-180 pts)"
# - Set x- and y- axis limits to 0 (minimum) and None (maximum; None will auto-set it)
#
# ### Sample Plot
#
# ![Seaborn plot of Pokemon Attack vs. Speed, with improved titles and limits](images/pokemon_attack_speed_3.png)
#
# We're getting there!

# %%
pokemon = pd.read_csv('data/lab05_task1.csv', index_col=0)
sns.set_theme(style="darkgrid", font_scale=1.5)
ax_pokemon_plot1 = sns.scatterplot(x='Attack', y='Speed', data=pokemon)
ax_pokemon_plot1.set(xlabel='Pokemon Attack Points (0-190 pts)', ylabel='Pokemon Speed Points (0-180 pts)', title='Relationship between Pokemon')
# Out:
# [Text(0.5, 0, 'Pokemon Attack Points (0-190 pts)'),
#  Text(0, 0.5, 'Pokemon Speed Points (0-180 pts)'),
#  Text(0.5, 1.0, 'Relationship between Pokemon')]

# %% [markdown]
# ## 2.4. Research question

# %% [markdown]
# ### 2.4.1 Come up with at least two research questions about your dataset that will require data visualizations to help answer.
#
# Recall that for this purpose, you should only aim for "Descriptive" or "Exploratory" research questions.
#
# **Hint1: You are welcome to calculate any columns that you think might be useful to answer the question (or re-add dropped columns like 'Generation', 'Sp. Atk', 'Sp. Def'.***
#
# **Hint2: Try not to overthink this; this is a toy dataset about Pokémon, you're not going to solve climate change or cure world hunger. Focus your research questions on the various Pokémon attributes, and the types.**

# %% [markdown]
# #### # Your solution here:
#
# **1. Sample Research Question:** Which Pokemon Types are the best, as determined by the Weighted Score?
#
# **2. Your RQ 1:Which Pokemon Types are the best, as determined by the speed?**
# **Answer - Flying**
#
# **3. Your RQ 2: Which Pokemon Types are the best, as determined by the defense?**
# **Answer - Steel**

# %% [markdown]
# ## 2.5 Answer your research questions with visualizations
#
# Remember to refer to the [`seaborn` gallery](https://seaborn.pydata.org/examples/index.html) for ideas on different visualizations.

# %%
df = pd.read_csv('https://github.com/firasm/bits/raw/master/pokemon.csv')

# Calculate the mean speed for each type
mean_speed = df.groupby('Type 1')['Speed'].mean().sort_values(ascending=False)

# Create a bar plot of the mean speed for each type
plt.figure(figsize=(12,6))
plt.bar(mean_speed.index, mean_speed.values, color='purple')

# Set plot and axis titles
plt.title('Average Speed of Each Pokemon Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Speed')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Show the plot
plt.show()

# %%
df = pd.read_csv('https://github.com/firasm/bits/raw/master/pokemon.csv')

mean_defense = df.groupby('Type 1')['Defense'].mean().sort_values(ascending=False)

# Create a bar plot of the mean defense for each type
plt.figure(figsize=(12,6))
plt.bar(mean_defense.index, mean_defense.values, color='green')

# Set plot and axis titles
plt.title('Average Defense of Each Pokemon Type')
plt.xlabel('Pokemon Type')
plt.ylabel('Defense')

# Rotate x-axis labels for better visibility
plt.xticks(rotation=45)

# Show the plot
plt.show()
